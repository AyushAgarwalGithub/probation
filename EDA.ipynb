# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("Ayush Agarwal.csv")

# %%
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 2995           1700     1          1.9         0   0       1          54
# 2996            609     0          1.8         1   0       0          13
# 2997           1185     0          1.4         0   1       1           8
# 2998           1533     1          0.5         1   0       0          50
# 2999           1270     1          0.5         0   4       1          35
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.describe()
# Out:
#        battery_power         blue  clock_speed     dual_sim           fc  \
# count    3000.000000  3000.000000  3000.000000  3000.000000  3000.000000
# mean     1241.849000     0.502000     1.528467     0.512000     4.404000
# std       437.063804     0.500079     0.820358     0.499939     4.383742
# min       500.000000     0.000000     0.500000     0.000000     0.000000
# 25%       863.750000     0.000000     0.700000     0.000000     1.000000
# 50%      1232.000000     1.000000     1.500000     1.000000     3.000000
# 75%      1619.000000     1.000000     2.300000     1.000000     7.000000
# max      1999.000000     1.000000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  3000.000000  3000.000000  3000.000000  3000.000000  3000.000000  ...
# mean      0.510000    32.581667     0.507000   140.003000     4.456333  ...
# std       0.499983    18.152810     0.285969    35.213809     2.289361  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  3000 non-null   int64
#  1   blue           3000 non-null   int64
#  2   clock_speed    3000 non-null   float64
#  3   dual_sim       3000 non-null   int64
#  4   fc             3000 non-null   int64
#  5   four_g         3000 non-null   int64
#  6   int_memory     3000 non-null   int64
#  7   m_dep          3000 non-null   float64
#  8   mobile_wt      3000 non-null   int64
#  9   n_cores        3000 non-null   int64
#  10  pc             3000 non-null   int64
#  11  px_height      3000 non-null   int64
#  12  px_width       3000 non-null   int64
#  13  ram            3000 non-null   int64
#  14  sc_h           3000 non-null   int64
#  15  sc_w           3000 non-null   int64
#  16  talk_time      3000 non-null   int64
#  17  three_g        3000 non-null   int64
# ...

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.shape
# Out:
# (3000, 21)

# %%
df['price_range'].value_counts()[0]
# Out:
# 500

# %%
df['price_range'].value_counts()
# Out:
# price_range
# 1.0    500
# 2.0    500
# 3.0    500
# 0.0    500
# Name: count, dtype: int64

# %%
df['price_range'].mean()
# Out:
# 1.5

# %%
sns.lineplot(y="price_range",x="battery_power",data=df)
# Out:
# <Axes: xlabel='battery_power', ylabel='price_range'>

# %%
#as we can see here that price is variable so we will drop this column

# %%
df.mode(dropna=True)
# Out:
#    battery_power  blue  clock_speed  dual_sim   fc  four_g  int_memory  m_dep  \
# 0         1715.0   1.0          0.5       1.0  0.0     1.0        44.0    0.1
# 1            NaN   NaN          NaN       NaN  NaN     NaN         NaN    NaN
# 2            NaN   NaN          NaN       NaN  NaN     NaN         NaN    NaN
# 3            NaN   NaN          NaN       NaN  NaN     NaN         NaN    NaN
#
#    mobile_wt  n_cores  ...  px_height  px_width     ram  sc_h  sc_w  \
# 0      101.0      4.0  ...       98.0    1247.0  2610.0  17.0   1.0
# 1        NaN      NaN  ...      371.0    1552.0  2819.0   NaN   NaN
# 2        NaN      NaN  ...        NaN       NaN  3142.0   NaN   NaN
# 3        NaN      NaN  ...        NaN       NaN     NaN   NaN   NaN
#
#    talk_time  three_g  touch_screen  wifi  price_range
# 0        7.0      1.0           1.0   1.0          0.0
# 1        NaN      NaN           NaN   NaN          1.0
# 2        NaN      NaN           NaN   NaN          2.0
# ...

# %%
df.dropna(axis=0,inplace=True)

# %%
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
s=df.corr()
sns.heatmap(s,cbar=True)
# Out:
# <Axes: >

# %%
sns.barplot(y="battery_power",x="price_range",data=df)
plt.show()

# %%
# very expensive  phones have more battery

# %%
sns.barplot(y="ram",x="price_range",data=df)
plt.show()

# %%
#expensive phones also have more ram

# %%
sns.barplot(y="sc_w",x="price_range",data=df)
plt.show()

# %%
sns.barplot(y="",x="price_range",data=df)
plt.show()

# %%
sns.countplot(x="sc_h",data=df)
plt.show()

# %%
#most phones have a height of 17

# %%
sns.countplot(x="sc_w",data=df)
plt.show()

# %%
#most of the phones have a small width

# %%
sns.lineplot(x="sc_h",y="sc_w",data=df)
plt.show()

# %%
#it shows that height of the phne is increasin wight increase in width

# %%
sns.barplot(y="n_cores",x="wifi",data=df)
plt.show()

# %%
sns.barplot(x="wifi",y="battery_power",data=df,hue="blue")
plt.show()

# %%
sns.barplot(y="price_range",x="fc",data=df)
plt.show()

# %%
#camera with 17 fc pixels are more expensive

# %%
sns.countplot(x="clock_speed",data=df)
plt.show()

# %%
#most phones have a clock speed of .5

# %%
sns.lineplot(y="m_dep",x="price_range",data=df)
plt.show()

# %%
#cheap phones have a greater mobile depth

# %%
sns.barplot(x="price_range",y="pc",data=df)
plt.show()

# %%
#vvery expensive mobiles have more pc

# %%
sns.lineplot(x="price_range",y="int_memory",data=df)
plt.show()

# %%
#very expesive mobiles have more int_memory followed bye cheap then expensive then very cheap

# %%
sns.histplot(x="int_memory",data=df)
plt.show()

# %%
#most of the phones have an int memory of 15
